# %% [markdown]
# # **GSLC**

# %%
from scipy.interpolate import interp1d
from scipy.interpolate import CubicSpline
import matplotlib.pyplot as plt
plt.style.use('seaborn-poster')
# Out:
# <ipython-input-1-2cf545a5a2b9>:4: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-poster')

# %%
x=[0,1,2,3,4,5]
y=[1,3,2,5,3,2]

# %%
f=interp1d(x,y)
y_lin=f(3.5)
y_lin
# Out:
# array(4.)

# %%
plt.plot(x,y,'-ob')
plt.plot(3.5,y_lin,'ro')
plt.show()

# %%
import numpy as np

f= CubicSpline(x,y, bc_type='natural')
x_cub=np.linspace(0,5,100)
y_cub=f(x_cub)

y_ask=f(3.5)
y_ask
# Out:
# array(4.43241627)

# %%
plt.plot(x,y,'ob')
plt.plot(x_cub, y_cub, 'b')
plt.plot(3.5,f(3.5), 'ro')
plt.show()

# %% [markdown]
# **PPT S3-EIGEN VALUE & VECTOR**

# %% [markdown]
# skalar = semua nilai dalam matrix
#
# vektor = vektor baris dan vektor kolom
#
# tensor = kumpulan matrix
#
# cari nilai skalar dan nilai vektor
#
# eigen vektor --> 0 sampai 1 (makin mendekati 1 -> smallest)
#
# eigen value- skalar --> proses normalisasi

# %%
# LARGEST EIIGEN VALUE
# power method
import numpy as np
def normalize(x):
  fac = abs(x).max()
  x_n = x / x.max()
  return fac, x_n
x= np.array([1,1])
a=np.array([[0,2], [2,3]])

for i in range(8):
  x = np.dot(a,x)
  lambda_1, x= normalize(x)

print('Eigenvalue:', lambda_1)
print('Eigenvector', x)
# Out:
# Eigenvalue: 3.999949137887188
# Eigenvector [0.50000636 1.        ]

# %%
# SMALLEST EIGEN VALUE
# inverse power method

from numpy.linalg import inv
a_inv = inv(a)

for i in range(8):
  x= np.dot(a_inv, x)
  lambda_1, x = normalize(x)

print('Eigenvalue:', lambda_1)
print('Eigenvector:', x)
# Out:
# Eigenvalue: 0.20000000000024853
# Eigenvector: [1. 1.]

# %%
# EIGENVALUE & EIGENVECTORS - MATRIX A (2x2)

import numpy as np
from numpy.linalg import eig
a=np.array([[0,2], [2,3]])
w, v=eig(a)
print('E-value:', w)
print('E-vector', v)
# Out:
# E-value: [-1.  4.]
# E-vector [[-0.89442719 -0.4472136 ]
#  [ 0.4472136  -0.89442719]]

# %%
# matrix 3x3

import numpy as np
from numpy.linalg import eig

a=np.array([[2,2,4], [1,3,5], [2,3,4]])
w, v=eig(a)
print('E-value:', w)
print('E-vector', v)
# Out:
# E-value: [ 8.80916362  0.92620912 -0.73537273]
# E-vector [[-0.52799324 -0.77557092 -0.36272811]
#  [-0.604391    0.62277013 -0.7103262 ]
#  [-0.59660259 -0.10318482  0.60321224]]

# %%
# eigen 1
import numpy as np
from numpy.linalg import eig

a = np.array([[214, 214, 216,115],
              [214, 216, 197,113],
              [214,215,199,141],
              [212,212,215,172]])
w, v=eig(a)
print('E-value:', w)
print('E-vector', v)
# Out:
# E-value: [ 7.65281198e+02  4.41657081e+01  6.44951760e-01 -9.09185807e+00]
# E-vector [[ 0.49190884  0.27657672  0.72196536  0.76788561]
#  [ 0.47938326  0.40187866 -0.69147078 -0.30055231]
#  [ 0.49938209 -0.15860527 -0.02400689 -0.55462935]
#  [ 0.52804821 -0.85839573 -0.00760625  0.11138353]]

# %%
# eigen 2
import numpy as np
from numpy.linalg import eig

b = np.array([[117, 215, 214, 214],
              [136, 192, 216,213],
              [161,201,215,214],
              [167,214,212,213]])
w, v=eig(b)
print('E-value:', w)
# Out:
# E-value: [ 7.80308173e+02+0.j         -2.15668566e+01+5.83671879j
#  -2.15668566e+01-5.83671879j -1.74460227e-01+0.j        ]

# %%
# eigen 3
import numpy as np
from numpy.linalg import eig

c = np.array([[212, 216, 204, 155],
              [215, 187, 71,117],
              [219,121,31,99],
              [217,108,46,82]])
w, v=eig(c)
print('E-value:', w)
# Out:
# E-value: [ 611.5236557  -116.28433306   31.16533653  -14.40465917]

# %%
# eigen 4
import numpy as np
from numpy.linalg import eig

d = np.array([[159, 203, 216, 212],
              [140, 73, 188,215],
              [139,34,122,219],
              [124,47,109,218]])
w, v=eig(d)
print('E-value:', w)
# Out:
# E-value: [587.67818224 +0.j         -19.55788416+41.60521595j
#  -19.55788416-41.60521595j  23.43758609 +0.j        ]
